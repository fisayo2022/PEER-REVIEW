# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Fisayo Sofuwa
#
# Desired occupation- Data scientist

# %% [markdown]
# I am interested in data science because I enjoy discovering hidden patterns, making predictions and genrally making peoples and organizations business lives simpler and stress free

# %% [markdown]
# ### My code is meant to solve the basic math equation

# %%
2+2*10
# Out:
# 22

# %% [markdown]
# |age | class | name |
# | --- | --- | --- |
# |8 | grade 2 | Rona |
# | 4 |GRADE 3 | Ewe |
#
#
# 1. number
# 2. this
# 3. as
# 4. a
# 5. list
#
# *****
#
# * opera
# * google
# * java
#
# ~~i enjoy data science~~
